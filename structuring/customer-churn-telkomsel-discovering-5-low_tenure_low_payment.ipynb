# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib as mlp
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Overview

# %%
data = pd.read_csv('Telco_Customer_Engineeredv2.csv')

# %%
data.head().style.background_gradient()
# Out:
# <style type="text/css">
# #T_fbbb0_row0_col0, #T_fbbb0_row0_col1, #T_fbbb0_row0_col11, #T_fbbb0_row0_col13, #T_fbbb0_row0_col14, #T_fbbb0_row0_col16, #T_fbbb0_row1_col1, #T_fbbb0_row1_col13, #T_fbbb0_row1_col14, #T_fbbb0_row1_col15, #T_fbbb0_row1_col17, #T_fbbb0_row2_col13, #T_fbbb0_row2_col14, #T_fbbb0_row3_col13, #T_fbbb0_row3_col14, #T_fbbb0_row4_col13, #T_fbbb0_row4_col14 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_fbbb0_row0_col15 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_fbbb0_row0_col17, #T_fbbb0_row2_col17, #T_fbbb0_row3_col17 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_fbbb0_row1_col0 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_fbbb0_row1_col11 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_fbbb0_row1_col16 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_fbbb0_row2_col0 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_fbbb0_row2_col1 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_fbbb0_row2_col11 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_fbbb0_row2_col15, #T_fbbb0_row3_col11, #T_fbbb0_row4_col0, #T_fbbb0_row4_col1, #T_fbbb0_row4_col16, #T_fbbb0_row4_col17 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_fbbb0_row2_col16 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_fbbb0_row3_col0 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_fbbb0_row3_col1 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_fbbb0_row3_col15 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_fbbb0_row3_col16 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_fbbb0_row4_col11 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_fbbb0_row4_col15 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fbbb0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fbbb0_level0_col0" class="col_heading level0 col0" >Customer ID</th>
#       <th id="T_fbbb0_level0_col1" class="col_heading level0 col1" >Tenure Months</th>
#       <th id="T_fbbb0_level0_col2" class="col_heading level0 col2" >Location</th>
#       <th id="T_fbbb0_level0_col3" class="col_heading level0 col3" >Device Class</th>
#       <th id="T_fbbb0_level0_col4" class="col_heading level0 col4" >Games Product</th>
#       <th id="T_fbbb0_level0_col5" class="col_heading level0 col5" >Music Product</th>
#       <th id="T_fbbb0_level0_col6" class="col_heading level0 col6" >Education Product</th>
#       <th id="T_fbbb0_level0_col7" class="col_heading level0 col7" >Call Center</th>
#       <th id="T_fbbb0_level0_col8" class="col_heading level0 col8" >Video Product</th>
#       <th id="T_fbbb0_level0_col9" class="col_heading level0 col9" >Use MyApp</th>
#       <th id="T_fbbb0_level0_col10" class="col_heading level0 col10" >Payment Method</th>
#       <th id="T_fbbb0_level0_col11" class="col_heading level0 col11" >Monthly Purchase (Thou. IDR)</th>
#       <th id="T_fbbb0_level0_col12" class="col_heading level0 col12" >Churn Label</th>
#       <th id="T_fbbb0_level0_col13" class="col_heading level0 col13" >Longitude</th>
#       <th id="T_fbbb0_level0_col14" class="col_heading level0 col14" >Latitude</th>
#       <th id="T_fbbb0_level0_col15" class="col_heading level0 col15" >CLTV (Predicted Thou. IDR)</th>
#       <th id="T_fbbb0_level0_col16" class="col_heading level0 col16" >Total Purchase</th>
#       <th id="T_fbbb0_level0_col17" class="col_heading level0 col17" >Num Product Used</th>
#       <th id="T_fbbb0_level0_col18" class="col_heading level0 col18" >Internet Access</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fbbb0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fbbb0_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_fbbb0_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_fbbb0_row0_col2" class="data row0 col2" >Jakarta</td>
#       <td id="T_fbbb0_row0_col3" class="data row0 col3" >Mid End</td>
#       <td id="T_fbbb0_row0_col4" class="data row0 col4" >Yes</td>
#       <td id="T_fbbb0_row0_col5" class="data row0 col5" >Yes</td>
#       <td id="T_fbbb0_row0_col6" class="data row0 col6" >No</td>
#       <td id="T_fbbb0_row0_col7" class="data row0 col7" >No</td>
#       <td id="T_fbbb0_row0_col8" class="data row0 col8" >No</td>
#       <td id="T_fbbb0_row0_col9" class="data row0 col9" >No</td>
#       <td id="T_fbbb0_row0_col10" class="data row0 col10" >Digital Wallet</td>
#       <td id="T_fbbb0_row0_col11" class="data row0 col11" >70.005000</td>
#       <td id="T_fbbb0_row0_col12" class="data row0 col12" >Yes</td>
#       <td id="T_fbbb0_row0_col13" class="data row0 col13" >106.816666</td>
#       <td id="T_fbbb0_row0_col14" class="data row0 col14" >-6.200000</td>
#       <td id="T_fbbb0_row0_col15" class="data row0 col15" >4210.700000</td>
#       <td id="T_fbbb0_row0_col16" class="data row0 col16" >140.010000</td>
#       <td id="T_fbbb0_row0_col17" class="data row0 col17" >2</td>
#       <td id="T_fbbb0_row0_col18" class="data row0 col18" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_fbbb0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fbbb0_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_fbbb0_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_fbbb0_row1_col2" class="data row1 col2" >Jakarta</td>
#       <td id="T_fbbb0_row1_col3" class="data row1 col3" >High End</td>
#       <td id="T_fbbb0_row1_col4" class="data row1 col4" >No</td>
#       <td id="T_fbbb0_row1_col5" class="data row1 col5" >No</td>
#       <td id="T_fbbb0_row1_col6" class="data row1 col6" >No</td>
#       <td id="T_fbbb0_row1_col7" class="data row1 col7" >No</td>
#       <td id="T_fbbb0_row1_col8" class="data row1 col8" >No</td>
#       <td id="T_fbbb0_row1_col9" class="data row1 col9" >No</td>
#       <td id="T_fbbb0_row1_col10" class="data row1 col10" >Pulsa</td>
#       <td id="T_fbbb0_row1_col11" class="data row1 col11" >91.910000</td>
#       <td id="T_fbbb0_row1_col12" class="data row1 col12" >Yes</td>
#       <td id="T_fbbb0_row1_col13" class="data row1 col13" >106.816666</td>
#       <td id="T_fbbb0_row1_col14" class="data row1 col14" >-6.200000</td>
#       <td id="T_fbbb0_row1_col15" class="data row1 col15" >3511.300000</td>
#       <td id="T_fbbb0_row1_col16" class="data row1 col16" >183.820000</td>
#       <td id="T_fbbb0_row1_col17" class="data row1 col17" >0</td>
#       <td id="T_fbbb0_row1_col18" class="data row1 col18" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_fbbb0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fbbb0_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_fbbb0_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_fbbb0_row2_col2" class="data row2 col2" >Jakarta</td>
#       <td id="T_fbbb0_row2_col3" class="data row2 col3" >High End</td>
#       <td id="T_fbbb0_row2_col4" class="data row2 col4" >No</td>
#       <td id="T_fbbb0_row2_col5" class="data row2 col5" >No</td>
#       <td id="T_fbbb0_row2_col6" class="data row2 col6" >Yes</td>
#       <td id="T_fbbb0_row2_col7" class="data row2 col7" >No</td>
#       <td id="T_fbbb0_row2_col8" class="data row2 col8" >Yes</td>
#       <td id="T_fbbb0_row2_col9" class="data row2 col9" >Yes</td>
#       <td id="T_fbbb0_row2_col10" class="data row2 col10" >Pulsa</td>
#       <td id="T_fbbb0_row2_col11" class="data row2 col11" >129.545000</td>
#       <td id="T_fbbb0_row2_col12" class="data row2 col12" >Yes</td>
#       <td id="T_fbbb0_row2_col13" class="data row2 col13" >106.816666</td>
#       <td id="T_fbbb0_row2_col14" class="data row2 col14" >-6.200000</td>
#       <td id="T_fbbb0_row2_col15" class="data row2 col15" >6983.600000</td>
#       <td id="T_fbbb0_row2_col16" class="data row2 col16" >1036.360000</td>
#       <td id="T_fbbb0_row2_col17" class="data row2 col17" >2</td>
#       <td id="T_fbbb0_row2_col18" class="data row2 col18" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_fbbb0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fbbb0_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_fbbb0_row3_col1" class="data row3 col1" >28</td>
#       <td id="T_fbbb0_row3_col2" class="data row3 col2" >Jakar

# %%
data.shape
# Out:
# (7043, 19)

# %% [markdown]
# The minority class (churned) covers 26% proportion of the dataset, this indicate the mildly imbalanced dataset.

# %%
data['Churn Label'].value_counts(normalize=True)*100
# Out:
# No     73.463013
# Yes    26.536987
# Name: Churn Label, dtype: float64

# %%
list_item = []
for col in data.columns:
    list_item.append([col, data[col].dtype, data[col].isna().sum(), 100*data[col].isna().sum()/len(data[col]), data[col].nunique(), data[col].unique()[:4]])
desc_df = pd.DataFrame(data=list_item, columns='feature data_type null_num null_pct unique_num unique_sample'.split())
desc_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_c1fbf_row0_col2, #T_c1fbf_row0_col3, #T_c1fbf_row1_col2, #T_c1fbf_row1_col3, #T_c1fbf_row2_col2, #T_c1fbf_row2_col3, #T_c1fbf_row2_col4, #T_c1fbf_row3_col2, #T_c1fbf_row3_col3, #T_c1fbf_row3_col4, #T_c1fbf_row4_col2, #T_c1fbf_row4_col3, #T_c1fbf_row4_col4, #T_c1fbf_row5_col2, #T_c1fbf_row5_col3, #T_c1fbf_row5_col4, #T_c1fbf_row6_col2, #T_c1fbf_row6_col3, #T_c1fbf_row6_col4, #T_c1fbf_row7_col2, #T_c1fbf_row7_col3, #T_c1fbf_row7_col4, #T_c1fbf_row8_col2, #T_c1fbf_row8_col3, #T_c1fbf_row8_col4, #T_c1fbf_row9_col2, #T_c1fbf_row9_col3, #T_c1fbf_row9_col4, #T_c1fbf_row10_col2, #T_c1fbf_row10_col3, #T_c1fbf_row10_col4, #T_c1fbf_row11_col2, #T_c1fbf_row11_col3, #T_c1fbf_row12_col2, #T_c1fbf_row12_col3, #T_c1fbf_row12_col4, #T_c1fbf_row13_col2, #T_c1fbf_row13_col3, #T_c1fbf_row13_col4, #T_c1fbf_row14_col2, #T_c1fbf_row14_col3, #T_c1fbf_row14_col4, #T_c1fbf_row15_col2, #T_c1fbf_row15_col3, #T_c1fbf_row16_col2, #T_c1fbf_row16_col3, #T_c1fbf_row17_col2, #T_c1fbf_row17_col3, #T_c1fbf_row17_col4, #T_c1fbf_row18_col2, #T_c1fbf_row18_col3, #T_c1fbf_row18_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c1fbf_row0_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c1fbf_row1_col4 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_c1fbf_row11_col4 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_c1fbf_row15_col4 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_c1fbf_row16_col4 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c1fbf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1fbf_level0_col0" class="col_heading level0 col0" >feature</th>
#       <th id="T_c1fbf_level0_col1" class="col_heading level0 col1" >data_type</th>
#       <th id="T_c1fbf_level0_col2" class="col_heading level0 col2" >null_num</th>
#       <th id="T_c1fbf_level0_col3" class="col_heading level0 col3" >null_pct</th>
#       <th id="T_c1fbf_level0_col4" class="col_heading level0 col4" >unique_num</th>
#       <th id="T_c1fbf_level0_col5" class="col_heading level0 col5" >unique_sample</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1fbf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c1fbf_row0_col0" class="data row0 col0" >Customer ID</td>
#       <td id="T_c1fbf_row0_col1" class="data row0 col1" >int64</td>
#       <td id="T_c1fbf_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_c1fbf_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_c1fbf_row0_col4" class="data row0 col4" >7043</td>
#       <td id="T_c1fbf_row0_col5" class="data row0 col5" >[0 1 2 3]</td>
#     </tr>
#     <tr>
#       <th id="T_c1fbf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c1fbf_row1_col0" class="data row1 col0" >Tenure Months</td>
#       <td id="T_c1fbf_row1_col1" class="data row1 col1" >int64</td>
#       <td id="T_c1fbf_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_c1fbf_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_c1fbf_row1_col4" class="data row1 col4" >73</td>
#       <td id="T_c1fbf_row1_col5" class="data row1 col5" >[ 2  8 28 49]</td>
#     </tr>
#     <tr>
#       <th id="T_c1fbf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c1fbf_row2_col0" class="data row2 col0" >Location</td>
#       <td id="T_c1fbf_row2_col1" class="data row2 col1" >object</td>
#       <td id="T_c1fbf_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_c1fbf_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_c1fbf_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_c1fbf_row2_col5" class="data row2 col5" >['Jakarta' 'Bandung']</td>
#     </tr>
#     <tr>
#       <th id="T_c1fbf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c1fbf_row3_col0" class="data row3 col0" >Device Class</td>
#       <td id="T_c1fbf_row3_col1" class="data row3 col1" >object</td>
#       <td id="T_c1fbf_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_c1fbf_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_c1fbf_row3_col4" class="data row3 col4" >3</td>
#       <td id="T_c1fbf_row3_col5" class="data row3 col5" >['Mid End' 'High End' 'Low End']</td>
#     </tr>
#     <tr>
#       <th id="T_c1fbf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c1fbf_row4_col0" class="data row4 col0" >Games Product</td>
#       <td id="T_c1fbf_row4_col1" class="data row4 col1" >object</td>
#       <td id="T_c1fbf_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_c1fbf_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_c1fbf_row4_col4" class="data row4 col4" >2</td>
#       <td id="T_c1fbf_row4_col5" class="data row4 col5" >['Yes' 'No']</td>
#     </tr>
#     <tr>
#       <th id="T_c1fbf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c1fbf_row5_col0" class="data row5 col0" >Music Product</td>
#       <td id="T_c1fbf_row5_col1" class="data row5 col1" >object</td>
#       <td id="T_c1fbf_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_c1fbf_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_c1fbf_row5_col4" class="data row5 col4" >2</td>
#       <td id="T_c1fbf_row5_col5" class="data row5 col5" >['Yes' 'No']</td>
#     </tr>
#     <tr>
#       <th id="T_c1fbf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c1fbf_row6_col0" class="data row6 col0" >Education Product</td>
#       <td id="T_c1fbf_row6_col1" class="data row6 col1" >object</td>
#       <td id="T_c1fbf_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_c1fbf_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_c1fbf_row6_col4" class="data row6 col4" >2</td>
#       <td id="T_c1fbf_row6_col5" class="data row6 col5" >['No' 'Yes']</td>
#     </tr>
#     <tr>
#       <th id="T_c1fbf_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c1fbf_row7_col0" class="data row7 col0" >Call Center</td>
#       <td id="T_c1fbf_row7_col1" class="data row7 col1" >object</td>
#       <td id="T_c1fbf_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_c1fbf_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_c1fbf_row7_col4" class="data row7 col4" >2</td>
#       <td id="T_c1fbf_row7_col5" class="data row7 col5" >['No' 'Yes']</td>
#     </tr>
#     <tr>
#       <th id="T_c1fbf_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c1fbf_row8_col0" class="data row8 col0" >Video Product</td>
#       <td id="T_c1fbf_row8_col1" class="data row8 col1" >object</td>
#       <td id="T_c1fbf_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_c1fbf_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_c1fbf_row8_col4" class="data row8 col4" >2</td>
#       <td id="T_c1fbf_row8_col5" class="data row8 col5" >['No' 'Yes']</td>
#     </tr>
#     <tr>
#       <th id="T_c1fbf_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c1fbf_row9_col0" class="data row9 col0" >Use MyApp</td>
#       <td id="T_c1fbf_row9_col1" class="data row9 col1" >object</td>
#       <td id="T_c1fbf_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_c1fbf_row9_col3" class="data row9 col3" >0.000000</td>
#       <td id="T_c1fbf_row9_col4" class="data row9 col4" >2</td>
#       <td id="T_c1fbf_row9_col5" class="data row9 col5" >['No' 'Yes']</td>
#     </tr>
#     <tr>
#       <th id="T_c1fbf_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c1fbf_row10_col0" class="data row10 col0" >Payment Method</td>
#       <td id="T_c1fbf_row10_col1" class="data row10 col1" >object</td>
#       <td id="T_c1fbf_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_c1fbf_row10_col3" class="data row10 col3" >0.000000</td>
#       <td id="T_c1fbf_row10_col4" class="data row10 col4" >4</td>
#       <td id="T_c1fbf_row10_col5" class="data row10 col5" >['Digital Wallet' 'Pulsa' 'Debit' 'Credit']</td>
#     </tr>
#     <tr>
#       <th id="T_c1fbf_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c1fbf_row11_col0" class="data row11 col0" >Monthly Purchase (Thou. IDR)</t

# %% [markdown]
# # 1 Months

# %%
df = data[data['Tenure Months'] == 1]
df.shape
# Out:
# (613, 19)

# %% [markdown]
# ## Bivariate

# %% [markdown]
# ### Numerical Analysis

# %%
numerical_cols = list(set(df.select_dtypes(exclude='object').columns) - set(['Longitude', 'Latitude']))
numerical_cols
# Out:
# ['Monthly Purchase (Thou. IDR)',
#  'Num Product Used',
#  'Total Purchase',
#  'Tenure Months',
#  'Customer ID',
#  'CLTV (Predicted Thou. IDR)']

# %%
x_text_coor = [35, 5800, 100]
y_text_coor = [800, 450, 800]
# Create Distplot for Each Numerical Feature
plt.figure(figsize=(17,8))
for i in range(0, len(numerical_cols)):
    plt.subplot(2, 3, i+1)
    sns.histplot(x=df[numerical_cols[i]], hue=df['Churn Label'], multiple='stack')
    plt.xlabel(numerical_cols[i])
    
    mean=round(df[numerical_cols[i]].mean(), 1)
    median=round(df[numerical_cols[i]].median(), 1)
    plt.axvline(mean, color='red', linestyle='--') 
    plt.axvline(median, color='blue', linestyle='--') 
    plt.legend(labels=[f'Mean({mean})',f'Median({median})', 'Churn', 'Not Churn'])
    #plt.text(x_text_coor[i], y_text_coor[i], f'mean={mean}', color='red', ha='left', va='top')
    #plt.tight_layout()

# %% [markdown]
# ### Categorical Analysis

# %%
cat_cols = df.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['Location', 'Device Class', 'Games Product', 'Music Product',
#        'Education Product', 'Call Center', 'Video Product', 'Use MyApp',
#        'Payment Method', 'Churn Label', 'Internet Access'],
#       dtype='object')

# %%
# Create Countplot for Each Categorical Feature
fig, axes = plt.subplots(4, 3, figsize=(20,12))
xy = [(0,0), (0,1), (0,2), (1,0), (1,1), (1,2), (2,0), (2,1), (2,2), (3,0), (3,1), (3,2), (4,0)]

for i in range(len(cat_cols)):
    if i == 0:
        sns.countplot(y=df[cat_cols[i]], palette='viridis',ax=axes[xy[i]], hue=df['Churn Label'])
    else:
        sns.countplot(y=df[cat_cols[i]], palette='viridis', order= df[cat_cols[i]].value_counts().index, ax=axes[xy[i]], hue=df['Churn Label'])
#axes[3, 1].axis('off')
axes[3, 2].axis('off')
plt.tight_layout()

# %% [markdown]
# # 6 Months or Less

# %%
df = data[data['Tenure Months'] <= 6]
df.shape
# Out:
# (1481, 19)

# %% [markdown]
# ## Bivariate

# %% [markdown]
# ### Numerical Analysis

# %%
numerical_cols = list(set(df.select_dtypes(exclude='object').columns) - set(['Longitude', 'Latitude']))
numerical_cols
# Out:
# ['Monthly Purchase (Thou. IDR)',
#  'Num Product Used',
#  'Total Purchase',
#  'Tenure Months',
#  'Customer ID',
#  'CLTV (Predicted Thou. IDR)']

# %%
x_text_coor = [35, 5800, 100]
y_text_coor = [800, 450, 800]
# Create Distplot for Each Numerical Feature
plt.figure(figsize=(17,8))
for i in range(0, len(numerical_cols)):
    plt.subplot(2, 3, i+1)
    sns.histplot(x=df[numerical_cols[i]], hue=df['Churn Label'], multiple='stack')
    plt.xlabel(numerical_cols[i])
    
    mean=round(df[numerical_cols[i]].mean(), 1)
    median=round(df[numerical_cols[i]].median(), 1)
    plt.axvline(mean, color='red', linestyle='--') 
    plt.axvline(median, color='blue', linestyle='--') 
    plt.legend(labels=[f'Mean({mean})',f'Median({median})', 'Churn', 'Not Churn'])
    #plt.text(x_text_coor[i], y_text_coor[i], f'mean={mean}', color='red', ha='left', va='top')
    #plt.tight_layout()

# %% [markdown]
# ### Categorical Analysis

# %%
cat_cols = df.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['Location', 'Device Class', 'Games Product', 'Music Product',
#        'Education Product', 'Call Center', 'Video Product', 'Use MyApp',
#        'Payment Method', 'Churn Label', 'Internet Access'],
#       dtype='object')

# %%
# Create Countplot for Each Categorical Feature
fig, axes = plt.subplots(4, 3, figsize=(20,12))
xy = [(0,0), (0,1), (0,2), (1,0), (1,1), (1,2), (2,0), (2,1), (2,2), (3,0), (3,1), (3,2), (4,0)]

for i in range(len(cat_cols)):
    if i == 0:
        sns.countplot(y=df[cat_cols[i]], palette='viridis',ax=axes[xy[i]], hue=df['Churn Label'])
    else:
        sns.countplot(y=df[cat_cols[i]], palette='viridis', order= df[cat_cols[i]].value_counts().index, ax=axes[xy[i]], hue=df['Churn Label'])
#axes[3, 1].axis('off')
axes[3, 2].axis('off')
plt.tight_layout()

# %% [markdown]
# ## Monthly Purchase less than 36 K

# %%
df = data[data['Monthly Purchase (Thou. IDR)'] < 36]
df.shape
# Out:
# (1606, 19)

# %% [markdown]
# ## Bivariate

# %% [markdown]
# ### Numerical Analysis

# %%
numerical_cols = list(set(df.select_dtypes(exclude='object').columns) - set(['Longitude', 'Latitude']))
numerical_cols
# Out:
# ['Monthly Purchase (Thou. IDR)',
#  'Num Product Used',
#  'Total Purchase',
#  'Tenure Months',
#  'Customer ID',
#  'CLTV (Predicted Thou. IDR)']

# %%
x_text_coor = [35, 5800, 100]
y_text_coor = [800, 450, 800]
# Create Distplot for Each Numerical Feature
plt.figure(figsize=(17,8))
for i in range(0, len(numerical_cols)):
    plt.subplot(2, 3, i+1)
    sns.histplot(x=df[numerical_cols[i]], hue=df['Churn Label'], multiple='stack')
    plt.xlabel(numerical_cols[i])
    
    mean=round(df[numerical_cols[i]].mean(), 1)
    median=round(df[numerical_cols[i]].median(), 1)
    plt.axvline(mean, color='red', linestyle='--') 
    plt.axvline(median, color='blue', linestyle='--') 
    plt.legend(labels=[f'Mean({mean})',f'Median({median})', 'Churn', 'Not Churn'])
    #plt.text(x_text_coor[i], y_text_coor[i], f'mean={mean}', color='red', ha='left', va='top')
    #plt.tight_layout()

# %% [markdown]
# ### Categorical Analysis

# %%
cat_cols = df.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['Location', 'Device Class', 'Games Product', 'Music Product',
#        'Education Product', 'Call Center', 'Video Product', 'Use MyApp',
#        'Payment Method', 'Churn Label', 'Internet Access'],
#       dtype='object')

# %%
# Create Countplot for Each Categorical Feature
fig, axes = plt.subplots(4, 3, figsize=(20,12))
xy = [(0,0), (0,1), (0,2), (1,0), (1,1), (1,2), (2,0), (2,1), (2,2), (3,0), (3,1), (3,2), (4,0)]

for i in range(len(cat_cols)):
    if i == 0:
        sns.countplot(y=df[cat_cols[i]], palette='viridis',ax=axes[xy[i]], hue=df['Churn Label'])
    else:
        sns.countplot(y=df[cat_cols[i]], palette='viridis', order= df[cat_cols[i]].value_counts().index, ax=axes[xy[i]], hue=df['Churn Label'])
#axes[3, 1].axis('off')
axes[3, 2].axis('off')
plt.tight_layout()

# %% [markdown]
# # References

# %% [markdown]
# - https://quantifyinghealth.com/interpret-logistic-regression-coefficients/
